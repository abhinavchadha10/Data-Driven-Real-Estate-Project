# %%
import pandas as pd
import numpy as np
import statistics

# %%
data1 = pd.read_excel('FloridaPropertyData.xlsx')
data1.head()
data1.shape
# Out:
# (7537, 37)

# %% [markdown]
# ## FIlter 1: Only selecting COmpleted Properties

# %%
filter1 = data1[data1.PROPERTY_STATUS == "Completed"]
filter1.shape
# Out:
# (5286, 37)

# %%
filter1['PROPERTY_RENTPERSQFT'] = filter1.PROPERTY_CURRENT_RENT/filter1.PROPERTY_SQFT
# Out:
# <ipython-input-4-c9bb1a89a8ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter1['PROPERTY_RENTPERSQFT'] = filter1.PROPERTY_CURRENT_RENT/filter1.PROPERTY_SQFT

# %%
filter1.head()
# Out:
#   PROPERTY_ID  MARKETID MARKET_NAME  SUBMARKET_CODE  \
# 0     15_1002        15       Miami            18.0
# 1     15_1028        15       Miami            18.0
# 2     15_1059        15       Miami            23.0
# 4     15_1105        15       Miami            25.0
# 7     15_1109        15       Miami            14.0
#
#                     SUBMARKET_NAME COUNTY_NAME  PROPERTY_NAME  \
# 0                          Hialeah  Miami-Dade     South Wind
# 1                          Hialeah  Miami-Dade     Blackstone
# 2                North Miami Beach  Miami-Dade    North Shore
# 4  Fontainebleau - University Park  Miami-Dade     Postmaster
# 7                      Miami Beach  Miami-Dade  Riviera Plaza
#
#                     PROPERTY_PRIORNAMES       PROPERTY_ADDRESS  \
# 0                             Southwind    149 East 3rd Street
# 1                                   NaN  3699 West 12th Avenue
# 2                                   NaN   2102 NE 167th Street
# 4                                   NaN     8800 SW 8th Street
# 7  Granite at Miami Beach, The, Riviera        337 20th Street
#
#        PROPERTY_CITY  ... PROPERTY_AFFORDABLEHOUSING  \
# 0            Hialeah  ...                          A
# 1            Hialeah  ...                          N
# 2  North Miami Beach  ...                          A
# 4              Miami  ...                          A
# 7        Miami Beach  ...                          A
#
#    PROPERTY_MILITARYHOUSING  PROPERTY_AGERESTRICTED  PROPERTY_FRACTUREDCONDO  \
# 0                         N                       N                      NaN
# 1                         N                       N                      NaN
# 2                         N                       N                      NaN
# 4                         N                       A                      NaN
# 7                         N                       N                      NaN
#
#    PROPERTY_ADAPTIVEREUSE  PROPERTY_SINGLEFAMILYRENTAL  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     0.0                          NaN
# 4                     NaN                          NaN
# 7                     1.0                          NaN
#
#    PROPERTY_CURRENT_OCCUPANCY  PROPERTY_CURRENT_RENT  \
# 0                         NaN                    NaN
# 1                        97.4                 1135.0
# 2                         NaN                    NaN
# 4                         NaN                    NaN
# 7                         NaN                    NaN
#
#                                  PROPERTY_MATRIX_URL PROPERTY_RENTPERSQFT
# 0  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...                  NaN
# 1  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...             0.028734
# 2  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...                  NaN
# 4  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...                  NaN
# 7  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...                  NaN
#
# [5 rows x 38 columns]

# %%
filter1['PROPERTY_RENTPERSQFTALLUNITS'] = filter1['PROPERTY_RENTPERSQFT']*filter1.PROPERTY_UNITS
# Out:
# <ipython-input-6-4e663cff939b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter1['PROPERTY_RENTPERSQFTALLUNITS'] = filter1['PROPERTY_RENTPERSQFT']*filter1.PROPERTY_UNITS

# %%
filter1.head()
# Out:
#   PROPERTY_ID  MARKETID MARKET_NAME  SUBMARKET_CODE  \
# 0     15_1002        15       Miami            18.0
# 1     15_1028        15       Miami            18.0
# 2     15_1059        15       Miami            23.0
# 4     15_1105        15       Miami            25.0
# 7     15_1109        15       Miami            14.0
#
#                     SUBMARKET_NAME COUNTY_NAME  PROPERTY_NAME  \
# 0                          Hialeah  Miami-Dade     South Wind
# 1                          Hialeah  Miami-Dade     Blackstone
# 2                North Miami Beach  Miami-Dade    North Shore
# 4  Fontainebleau - University Park  Miami-Dade     Postmaster
# 7                      Miami Beach  Miami-Dade  Riviera Plaza
#
#                     PROPERTY_PRIORNAMES       PROPERTY_ADDRESS  \
# 0                             Southwind    149 East 3rd Street
# 1                                   NaN  3699 West 12th Avenue
# 2                                   NaN   2102 NE 167th Street
# 4                                   NaN     8800 SW 8th Street
# 7  Granite at Miami Beach, The, Riviera        337 20th Street
#
#        PROPERTY_CITY  ... PROPERTY_MILITARYHOUSING  PROPERTY_AGERESTRICTED  \
# 0            Hialeah  ...                        N                       N
# 1            Hialeah  ...                        N                       N
# 2  North Miami Beach  ...                        N                       N
# 4              Miami  ...                        N                       A
# 7        Miami Beach  ...                        N                       N
#
#    PROPERTY_FRACTUREDCONDO  PROPERTY_ADAPTIVEREUSE  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     0.0
# 4                      NaN                     NaN
# 7                      NaN                     1.0
#
#    PROPERTY_SINGLEFAMILYRENTAL  PROPERTY_CURRENT_OCCUPANCY  \
# 0                          NaN                         NaN
# 1                          NaN                        97.4
# 2                          NaN                         NaN
# 4                          NaN                         NaN
# 7                          NaN                         NaN
#
#    PROPERTY_CURRENT_RENT                                PROPERTY_MATRIX_URL  \
# 0                    NaN  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...
# 1                 1135.0  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...
# 2                    NaN  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...
# 4                    NaN  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...
# 7                    NaN  matrix.pi-ei.com/PropertyDetail/All?MarketID=1...
#
#   PROPERTY_RENTPERSQFT PROPERTY_RENTPERSQFTALLUNITS
# 0                  NaN                          NaN
# 1             0.028734                     2.183797
# 2                  NaN                          NaN
# 4                  NaN                          NaN
# 7                  NaN                          NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Filter 2: Removing Properties with no Rent information

# %%
filter2 = filter1.dropna(subset = ['PROPERTY_RENTPERSQFTALLUNITS'])

# %%
filter2.shape
# Out:
# (3821, 39)

# %%
filter2.groupby(['MARKET_NAME','SUBMARKET_NAME']).mean()
# Out:
#                                                         MARKETID  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                  55.0
#                              Coral Springs - North          55.0
#                              Coral Springs - South          55.0
#                              Dania Beach                    55.0
#                              Davie                          55.0
# ...                                                          ...
# West Palm Beach - Boca Raton Wellington                     56.0
#                              West Palm Beach - Central      56.0
#                              West Palm Beach - North        56.0
#                              West Palm Beach - South        56.0
#                              West Palm Beach - West         56.0
#
#                                                         SUBMARKET_CODE  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                        12.0
#                              Coral Springs - North                14.0
#                              Coral Springs - South                15.0
#                              Dania Beach                          22.0
#                              Davie                                21.0
# ...                                                                ...
# West Palm Beach - Boca Raton Wellington                           11.0
#                              West Palm Beach - Central             6.0
#                              West Palm Beach - North               5.0
#                              West Palm Beach - South               8.0
#                              West Palm Beach - West                7.0
#
#                                                         PROPERTY_ZIPCODE  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                  33069.157895
#                              Coral Springs - North          33065.000000
#                              Coral Springs - South          33071.000000
#                              Dania Beach                    33041.000000
#                              Davie                          33275.142857
# ...                                                                  ...
# West Palm Beach - Boca Raton Wellington                     33418.700000
#                              West Palm Beach - Central      33408.900000
#                              West Palm Beach - North        33404.666667
#                              West Palm Beach - South        33412.000000
#                              West Palm Beach - West         33411.500000
#
#                                                         PROPERTY_LATITUDE  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                      26.281917
#                              Coral Springs - North              26.269850
#                              Coral Springs - South              26.243317
#                              Dania Beach                        26.043662
#                              Davie                              26.070371
# ...                                                                   ...
# West Palm Beach - Boca Raton Wellington                         26.655907
#                              West Palm Beach - Central          26.713469
#                              West Palm Beach - North            26.729801
#                              West Palm Beach - South            26.692965
#                              West Palm Beach - West             26.733001
#
#                                                         PROPERTY_LONGITUDE  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                      -80.191077
#                              Coral Springs - North              -80.243152
#                              Coral Springs - South              -80.270409
#                              Dania Beach                        -80.163596
#                              Davie                              -80.240457
# ...                                                                    ...
# West Palm Beach - Boca Raton Wellington                         -80.221577
#                              West Palm Beach - Central          -80.054091
#                              West Palm Beach - North            -80.073101
#                              West Palm Beach - South            -80.124346
#                              West Palm Beach - West             -80.115819
#
#                                                         PROPERTY_PHONE  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                9.230919e+09
#                              Coral Springs - North        8.912132e+09
#                              Coral Springs - South        9.545192e+09
#                              Dania Beach                  9.547130e+09
#                              Davie                        9.450556e+09
# ...                                                                ...
# West Palm Beach - Boca Raton Wellington                   5.616565e+09
#                              West Palm Beach - Central    5.616539e+09
#                              West Palm Beach - North      5.615275e+09
#                              West Palm Beach - South      5.614678e+09
#                              West Palm Beach - West       5.832778e+09
#
#                                                         PROPERTY_UNITS  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                  311.473684
#                              Coral Springs - North          224.833333
#                              Coral Springs - South          318.428571
#                              Dania Beach                    243.090909
#                              Davie                          262.809524
# ...                                                                ...
# West Palm Beach - Boca Raton Wellington                     271.400000
#                              West Palm Beach - Central      182.700000
#                              West Palm Beach - North        200.833333
#                              West Palm Beach - South        209.923077
#                              West Palm Beach - West         260.625000
#
#                                                         PROPERTY_SQFT  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek              326865.000000
#                              Coral Springs - North      250562.833333
#                              Coral Springs - South      360102.142857
#                              Dania Beach                212782.909091
#                              Davie                      256202.619048
# ...                                                               ...
# West Palm Beach - Boca Raton Wellington                 320183.900000
#                              West Palm Beach - Central  173325.100000
#                              West Palm Beach - North    180456.916667
#                              West Palm Beach - South    184738.000000
#                              West Palm Beach - West     267420.062500
#
#                                                         PROPERTY_ACRES  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                   20.800526
#                              Coral Springs - North           13.781667
#                              Coral Springs - South           17.264286
#                              Dania Beach                     12.305455
#                              Davie                           15.589048
# ...                                                                ...
# West Palm Beach - Boca Raton Wellington                      20.782000
#                              West Palm Beach - Central        2.056000
#                              West Palm Beach - North          8.257500
#                              West Palm Beach - South         15.302308
#                              West Palm Beach - West          17.060625
#
#                                                         PROPERTY_MIXEDUSE  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                       0.000000
#                              Coral Springs - North               0.000000
#                              Coral Springs - South               0.000000
#                              Dania Beach                         0.090909
#                              Davie                               0.047619
# ...                                                                   ...
# West Palm Beach - Boca Raton Wellington                          0.000000
#                              West Palm Beach - Central           0.200000
#                              West Palm Beach - North             0.000000
#                              West Palm Beach - South             0.076923
#                              West Palm Beach - West              0.000000
#
#                                                         PROPERTY_ADAPTIVEREUSE  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                                 0.0
#                              Coral Springs - North                         0.0
#                              Coral Springs - South                         NaN
#                              Dania Beach                                   0.0
#                              Davie                                         0.0
# ...                                                                        ...
# West Palm Beach - Boca Raton Wellington                                    0.0
#                              West Palm Beach - Central                     0.0
#                              West Palm Beach - North                       0.0
#                              West Palm Beach - South                       0.0
#                              West Palm Beach - West                        0.0
#
#                                                         PROPERTY_SINGLEFAMILYRENTAL  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                                      NaN
#                              Coral Springs - North                              NaN
#                              Coral Springs - South                              NaN
#                              Dania Beach                                        NaN
#                              Davie                                              NaN
# ...                                                                             ...
# West Palm Beach - Boca Raton Wellington                                         NaN
#                              West Palm Beach - Central                          NaN
#                              West Palm Beach - North                            NaN
#                              West Palm Beach - South                            NaN
#                              West Palm Beach - West                             NaN
#
#                                                         PROPERTY_CURRENT_OCCUPANCY  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                               96.252632
#                              Coral Springs - North                       97.772222
#                              Coral Springs - South                       97.742857
#                              Dania Beach                                 97.318182
#                              Davie                                       97.075000
# ...                                                                            ...
# West Palm Beach - Boca Raton Wellington                                  97.760000
#                              West Palm Beach - Central                   93.090000
#                              West Palm Beach - North                     97.225000
#                              West Palm Beach - South                     92.330769
#                              West Palm Beach - West                      94.837500
#
#                                                         PROPERTY_CURRENT_RENT  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                        2208.736842
#                              Coral Springs - North                2131.611111
#                              Coral Springs - South                2239.571429
#                              Dania Beach                          1937.818182
#                              Davie                                2121.238095
# ...                                                                       ...
# West Palm Beach - Boca Raton Wellington                           2451.400000
#                              West Palm Beach - Central            3242.200000
#                              West Palm Beach - North              1693.250000
#                              West Palm Beach - South              1791.076923
#                              West Palm Beach - West               1964.750000
#
#                                                         PROPERTY_RENTPERSQFT  \
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                          0.007273
#                              Coral Springs - North                  0.010518
#                              Coral Springs - South                  0.006562
#                              Dania Beach                            0.014166
#                              Davie                                  0.013198
# ...                                                                      ...
# West Palm Beach - Boca Raton Wellington                             0.008959
#                              West Palm Beach - Central              0.022979
#                              West Palm Beach - North                0.015034
#                              West Palm Beach - South                0.013407
#                              West Palm Beach - West                 0.011015
#
#                                                         PROPERTY_RENTPERSQFTALLUNITS
# MARKET_NAME                  SUBMARKET_NAME
# Fort Lauderdale              Coconut Creek                                  2.119500
#                              Coral Springs - North                          1.953580
#                              Coral Springs - South                          1.965330
#                              Dania Beach                                    2.166891
#                              Davie                                          2.266825
# ...                                                                              ...
# West Palm Beach - Boca Raton Wellington                                     2.130359
#                              West Palm Beach - Central                      3.165763
#                              West Palm Beach - North                        2.022361
#                              West Palm Beach - South                        2.043407
#                              West Palm Beach - West                         1.924074
#
# [293 rows x 16 columns]

# %% [markdown]
# ## Filter 3: Removing properties with no SQFT information

# %%
filter3 = filter2[filter2.PROPERTY_SQFT > 0]

# %%
filter3.shape
# Out:
# (3819, 39)

# %% [markdown]
# ## Filter 4: Removing Student, Affordable, Military, Age Restricted Housing

# %%
filter4 = filter3[(filter3.PROPERTY_STUDENTHOUSING == 'N') & (filter3.PROPERTY_AFFORDABLEHOUSING == 'N') & (filter3.PROPERTY_MILITARYHOUSING == 'N') & (filter3.PROPERTY_AGERESTRICTED == 'N')]

# %%
filter4.shape
# Out:
# (2896, 39)

# %% [markdown]
# ## Filter 5: Removing Property with no Submarket

# %%
filter5 = filter4.dropna(subset = ['SUBMARKET_NAME'])

# %%
filter5.shape
# Out:
# (2896, 39)

# %%
mean_submarket = filter5.groupby(['SUBMARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.mean()
mean_submarket_dict = mean_submarket.to_dict()
filter5['mean_submarket'] = filter5['SUBMARKET_NAME'].map(mean_submarket_dict)

# %%
min_submarket = filter5.groupby(['SUBMARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.min()
min_submarket_dict = min_submarket.to_dict()
filter5['min_submarket'] = filter5['SUBMARKET_NAME'].map(min_submarket_dict)

# %%
max_submarket = filter5.groupby(['SUBMARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.max()
max_submarket_dict = max_submarket.to_dict()
filter5['max_submarket'] = filter5['SUBMARKET_NAME'].map(max_submarket_dict)

# %%
mean_market = filter5.groupby(['MARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.mean()
mean_market_dict = mean_market.to_dict()
filter5['mean_market'] = filter5['MARKET_NAME'].map(mean_market_dict)

# %%
min_market = filter5.groupby(['MARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.min()
min_market_dict = min_market.to_dict()
filter5['min_market'] = filter5['MARKET_NAME'].map(min_market_dict)

# %%
max_market = filter5.groupby(['MARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.max()
max_market_dict = max_market.to_dict()
filter5['max_market'] = filter5['MARKET_NAME'].map(max_market_dict)

# %%
filter5.shape
# Out:
# (2896, 45)

# %%
filter5.columns
# Out:
# Index(['PROPERTY_ID', 'MARKETID', 'MARKET_NAME', 'SUBMARKET_CODE',
#        'SUBMARKET_NAME', 'COUNTY_NAME', 'PROPERTY_NAME', 'PROPERTY_PRIORNAMES',
#        'PROPERTY_ADDRESS', 'PROPERTY_CITY', 'PROPERTY_STATE',
#        'PROPERTY_ZIPCODE', 'PROPERTY_LATITUDE', 'PROPERTY_LONGITUDE',
#        'PROPERTY_PHONE', 'PROPERTY_UNITS', 'PROPERTY_SQFT', 'PROPERTY_ACRES',
#        'PROPERTY_IMPRATING', 'PROPERTY_LOCRATING', 'PROPERTY_STATUS',
#        'PROPERTY_DATE_PLANNED', 'PROPERTY_DATE_UNDERCONSTRUCTION',
#        'PROPERTY_DATE_RENTUP', 'PROPERTY_DATECOMPLETED', 'PROPERTY_MIXEDUSE',
#        'PROPERTY_MIXEDUSE_NOTES', 'PROPERTY_STUDENTHOUSING',
#        'PROPERTY_AFFORDABLEHOUSING', 'PROPERTY_MILITARYHOUSING',
#        'PROPERTY_AGERESTRICTED', 'PROPERTY_FRACTUREDCONDO',
#        'PROPERTY_ADAPTIVEREUSE', 'PROPERTY_SINGLEFAMILYRENTAL',
#        'PROPERTY_CURRENT_OCCUPANCY', 'PROPERTY_CURRENT_RENT',
#        'PROPERTY_MATRIX_URL', 'PROPERTY_RENTPERSQFT',
#        'PROPERTY_RENTPERSQFTALLUNITS', 'mean_submarket', 'min_submarket',
#        'max_submarket', 'mean_market', 'min_market', 'max_market'],
#       dtype='object')

# %%
filter5 = filter5.loc[:,['PROPERTY_ID', 'MARKETID', 'MARKET_NAME', 'SUBMARKET_CODE', 'SUBMARKET_NAME', 'COUNTY_NAME', 'PROPERTY_NAME', 'PROPERTY_PRIORNAMES','PROPERTY_ADDRESS', 'PROPERTY_CITY', 'PROPERTY_STATE','PROPERTY_ZIPCODE', 'PROPERTY_LATITUDE', 'PROPERTY_LONGITUDE', 'PROPERTY_UNITS', 'PROPERTY_SQFT', 'PROPERTY_ACRES','PROPERTY_IMPRATING', 'PROPERTY_LOCRATING', 'PROPERTY_DATECOMPLETED','PROPERTY_CURRENT_OCCUPANCY', 'PROPERTY_CURRENT_RENT','PROPERTY_RENTPERSQFT','PROPERTY_RENTPERSQFTALLUNITS', 'mean_submarket', 'min_submarket','max_submarket', 'mean_market', 'min_market', 'max_market']]

# %%
filter5.shape
# Out:
# (2896, 30)

# %% [markdown]
# ## Filter 6: Removing Property with missing IMP/LOC rating

# %%
filter5['PROPERTY_IMPRATING'].isnull().sum()
filter5['PROPERTY_LOCRATING'].isnull().sum()
# Out:
# 0

# %%
filter5['PROPERTY_IMPRATING'].replace('', np.nan, inplace=True)
filter5['PROPERTY_LOCRATING'].replace('', np.nan, inplace=True)

# %%
filter6 = filter5.dropna(subset=['PROPERTY_IMPRATING','PROPERTY_LOCRATING'])

# %%
final_data = filter6

# %%
final_data.shape
# Out:
# (2890, 30)

# %%
final_data = final_data.reset_index(drop=True)

# %%
final_data.to_excel('Florida_FilterData.xlsx')
