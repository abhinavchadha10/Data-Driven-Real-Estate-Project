# %%
import pandas as pd
import numpy as np
import statistics

# %%
data1 = pd.read_excel('PropertyDataSouthWest.xlsx')
data1.head()
# Out:
#   PROPERTY_ID  MARKETID MARKET_NAME  SUBMARKET_CODE           SUBMARKET_NAME  \
# 0      36_103        36      Austin            38.0          San Marcos/Kyle
# 1     36_1091        36      Austin            22.0            Capital Plaza
# 2  36_1097559        36      Austin            10.0             Pflugerville
# 3  36_1140137        36      Austin            40.0  Outlying Bastrop County
# 4      36_115        36      Austin            38.0          San Marcos/Kyle
#
#   COUNTY_NAME        PROPERTY_NAME PROPERTY_PRIORNAMES  \
# 0        Hays  Executive Townhomes                 NaN
# 1      Travis        Capital Steps                 NaN
# 2      Travis  Old Gin Pforum, The                 NaN
# 3     Bastrop     Post Oak at Hill                 NaN
# 4        Hays              Langtry                 NaN
#
#          PROPERTY_ADDRESS PROPERTY_CITY  ... PROPERTY_STUDENTHOUSING  \
# 0     317 Craddock Avenue    San Marcos  ...                       N
# 1       5211 Cameron Road        Austin  ...                       N
# 2   310 East Pecan Street  Pflugerville  ...                     NaN
# 3  Highway 71 & Hill Road    Smithville  ...                     NaN
# 4     205 Craddock Avenue    San Marcos  ...                       N
#
#    PROPERTY_AFFORDABLEHOUSING  PROPERTY_MILITARYHOUSING  \
# 0                           N                         N
# 1                           N                         N
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                           N                         N
#
#    PROPERTY_AGERESTRICTED  PROPERTY_FRACTUREDCONDO  PROPERTY_ADAPTIVEREUSE  \
# 0                       N                      NaN                     NaN
# 1                       N                      NaN                     NaN
# 2                     NaN                      NaN                     NaN
# 3                     NaN                      NaN                     NaN
# 4                       N                      NaN                     NaN
#
#    PROPERTY_SINGLEFAMILYRENTAL  PROPERTY_CURRENT_OCCUPANCY  \
# 0                          NaN                        98.4
# 1                          NaN                       100.0
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                       100.0
#
#   PROPERTY_CURRENT_RENT                                PROPERTY_MATRIX_URL
# 0                1090.0  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
# 1                1027.0  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
# 2                   NaN  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
# 3                   NaN  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
# 4                1105.0  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
#
# [5 rows x 37 columns]

# %% [markdown]
# ## FIlter 1: Only selecting COmpleted Properties

# %%
filter1 = data1[data1.PROPERTY_STATUS == "Completed"]
filter1.shape
# Out:
# (10899, 37)

# %%
filter1['PROPERTY_RENTPERSQFT'] = filter1.PROPERTY_CURRENT_RENT/filter1.PROPERTY_SQFT
# Out:
# <ipython-input-7-c9bb1a89a8ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter1['PROPERTY_RENTPERSQFT'] = filter1.PROPERTY_CURRENT_RENT/filter1.PROPERTY_SQFT

# %%
filter1.head()
# Out:
#   PROPERTY_ID  MARKETID MARKET_NAME  SUBMARKET_CODE      SUBMARKET_NAME  \
# 0      36_103        36      Austin            38.0     San Marcos/Kyle
# 1     36_1091        36      Austin            22.0       Capital Plaza
# 4      36_115        36      Austin            38.0     San Marcos/Kyle
# 5  36_1155180        36      Austin             7.0  Jollyville - north
# 8  36_1211359        36      Austin            26.0            Pershing
#
#   COUNTY_NAME             PROPERTY_NAME PROPERTY_PRIORNAMES  \
# 0        Hays       Executive Townhomes                 NaN
# 1      Travis             Capital Steps                 NaN
# 4        Hays                   Langtry                 NaN
# 5  Williamson        Dalewood Townhomes                 NaN
# 8      Travis  Works at Pleasant Valley                 NaN
#
#       PROPERTY_ADDRESS PROPERTY_CITY  ... PROPERTY_AFFORDABLEHOUSING  \
# 0  317 Craddock Avenue    San Marcos  ...                          N
# 1    5211 Cameron Road        Austin  ...                          N
# 4  205 Craddock Avenue    San Marcos  ...                          N
# 5  9601 Dalewood Drive        Austin  ...                          N
# 8      2800 Lyons Road        Austin  ...                          A
#
#    PROPERTY_MILITARYHOUSING  PROPERTY_AGERESTRICTED  PROPERTY_FRACTUREDCONDO  \
# 0                         N                       N                      NaN
# 1                         N                       N                      NaN
# 4                         N                       N                      NaN
# 5                         N                       N                      NaN
# 8                         N                       N                      NaN
#
#    PROPERTY_ADAPTIVEREUSE  PROPERTY_SINGLEFAMILYRENTAL  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 4                     NaN                          NaN
# 5                     NaN                          1.0
# 8                     0.0                          NaN
#
#    PROPERTY_CURRENT_OCCUPANCY  PROPERTY_CURRENT_RENT  \
# 0                        98.4                 1090.0
# 1                       100.0                 1027.0
# 4                       100.0                 1105.0
# 5                       100.0                 1651.0
# 8                         NaN                    NaN
#
#                                  PROPERTY_MATRIX_URL PROPERTY_RENTPERSQFT
# 0  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...             0.017616
# 1  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...             0.031102
# 4  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...             0.021415
# 5  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...             0.030667
# 8  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...                  NaN
#
# [5 rows x 38 columns]

# %%
filter1['PROPERTY_RENTPERSQFTALLUNITS'] = filter1['PROPERTY_RENTPERSQFT']*filter1.PROPERTY_UNITS
# Out:
# <ipython-input-9-4e663cff939b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter1['PROPERTY_RENTPERSQFTALLUNITS'] = filter1['PROPERTY_RENTPERSQFT']*filter1.PROPERTY_UNITS

# %%
filter1.head()
# Out:
#   PROPERTY_ID  MARKETID MARKET_NAME  SUBMARKET_CODE      SUBMARKET_NAME  \
# 0      36_103        36      Austin            38.0     San Marcos/Kyle
# 1     36_1091        36      Austin            22.0       Capital Plaza
# 4      36_115        36      Austin            38.0     San Marcos/Kyle
# 5  36_1155180        36      Austin             7.0  Jollyville - north
# 8  36_1211359        36      Austin            26.0            Pershing
#
#   COUNTY_NAME             PROPERTY_NAME PROPERTY_PRIORNAMES  \
# 0        Hays       Executive Townhomes                 NaN
# 1      Travis             Capital Steps                 NaN
# 4        Hays                   Langtry                 NaN
# 5  Williamson        Dalewood Townhomes                 NaN
# 8      Travis  Works at Pleasant Valley                 NaN
#
#       PROPERTY_ADDRESS PROPERTY_CITY  ... PROPERTY_MILITARYHOUSING  \
# 0  317 Craddock Avenue    San Marcos  ...                        N
# 1    5211 Cameron Road        Austin  ...                        N
# 4  205 Craddock Avenue    San Marcos  ...                        N
# 5  9601 Dalewood Drive        Austin  ...                        N
# 8      2800 Lyons Road        Austin  ...                        N
#
#    PROPERTY_AGERESTRICTED  PROPERTY_FRACTUREDCONDO  PROPERTY_ADAPTIVEREUSE  \
# 0                       N                      NaN                     NaN
# 1                       N                      NaN                     NaN
# 4                       N                      NaN                     NaN
# 5                       N                      NaN                     NaN
# 8                       N                      NaN                     0.0
#
#    PROPERTY_SINGLEFAMILYRENTAL  PROPERTY_CURRENT_OCCUPANCY  \
# 0                          NaN                        98.4
# 1                          NaN                       100.0
# 4                          NaN                       100.0
# 5                          1.0                       100.0
# 8                          NaN                         NaN
#
#    PROPERTY_CURRENT_RENT                                PROPERTY_MATRIX_URL  \
# 0                 1090.0  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
# 1                 1027.0  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
# 4                 1105.0  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
# 5                 1651.0  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
# 8                    NaN  matrix.pi-ei.com/PropertyDetail/All?MarketID=3...
#
#   PROPERTY_RENTPERSQFT PROPERTY_RENTPERSQFTALLUNITS
# 0             0.017616                     1.074586
# 1             0.031102                     1.555118
# 4             0.021415                     1.199225
# 5             0.030667                     1.533361
# 8                  NaN                          NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Filter 2: Removing Properties with no Rent information

# %%
filter2 = filter1.dropna(subset = ['PROPERTY_RENTPERSQFTALLUNITS'])

# %%
filter2.shape
# Out:
# (9153, 39)

# %%
filter2.groupby(['MARKET_NAME','SUBMARKET_NAME']).mean()
# Out:
#                                       MARKETID  SUBMARKET_CODE  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central           112.0             1.0
#             Amarillo - South Central     112.0             4.0
#             Amarillo - Southeast         112.0             3.0
#             Amarillo - Southwest         112.0             5.0
#             Amarillo - West              112.0             6.0
# ...                                        ...             ...
# Tulsa       Tulsa - Northeast            111.0             5.0
#             Tulsa - South                111.0             4.0
#             Tulsa - Southeast            111.0             3.0
#             Union                        111.0             6.0
#             Washington County            111.0            25.0
#
#                                       PROPERTY_ZIPCODE  PROPERTY_LATITUDE  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central            79107.500000          35.227121
#             Amarillo - South Central      79110.166667          35.164096
#             Amarillo - Southeast          79118.000000          35.177839
#             Amarillo - Southwest          79113.941176          35.158413
#             Amarillo - West               79108.285714          35.192730
# ...                                                ...                ...
# Tulsa       Tulsa - Northeast             74113.333333          36.154961
#             Tulsa - South                 74123.700000          36.072488
#             Tulsa - Southeast             74126.476190          36.085698
#             Union                         74131.175000          36.055725
#             Washington County             74005.400000          36.740187
#
#                                       PROPERTY_LONGITUDE  PROPERTY_PHONE  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central               -101.813722    8.063813e+09
#             Amarillo - South Central         -101.881083    8.064628e+09
#             Amarillo - Southeast             -101.819387    8.068038e+09
#             Amarillo - Southwest             -101.917819    8.064262e+09
#             Amarillo - West                  -101.891752    8.087114e+09
# ...                                                  ...             ...
# Tulsa       Tulsa - Northeast                 -95.844296    9.184375e+09
#             Tulsa - South                     -95.969304    9.186135e+09
#             Tulsa - Southeast                 -95.940209    9.186327e+09
#             Union                             -95.884123    9.183815e+09
#             Washington County                 -95.931967    9.183349e+09
#
#                                       PROPERTY_UNITS  PROPERTY_SQFT  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central            142.666667  118405.833333
#             Amarillo - South Central      174.333333  128945.166667
#             Amarillo - Southeast          240.000000  240360.000000
#             Amarillo - Southwest          246.411765  212855.352941
#             Amarillo - West               171.619048  142474.238095
# ...                                              ...            ...
# Tulsa       Tulsa - Northeast             197.000000  173113.333333
#             Tulsa - South                 221.250000  174080.275000
#             Tulsa - Southeast             175.190476  144066.428571
#             Union                         299.850000  253433.600000
#             Washington County             138.600000  117177.600000
#
#                                       PROPERTY_ACRES  PROPERTY_MIXEDUSE  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central             12.226667           0.000000
#             Amarillo - South Central        7.032778           0.000000
#             Amarillo - Southeast           10.070000           0.000000
#             Amarillo - Southwest           10.742353           0.058824
#             Amarillo - West                 8.188571           0.000000
# ...                                              ...                ...
# Tulsa       Tulsa - Northeast              12.900000           0.000000
#             Tulsa - South                   9.421500           0.000000
#             Tulsa - Southeast               8.318571           0.000000
#             Union                          14.429250           0.000000
#             Washington County               7.530000           0.000000
#
#                                       PROPERTY_ADAPTIVEREUSE  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central                           NaN
#             Amarillo - South Central                     0.0
#             Amarillo - Southeast                         NaN
#             Amarillo - Southwest                         0.0
#             Amarillo - West                              NaN
# ...                                                      ...
# Tulsa       Tulsa - Northeast                            NaN
#             Tulsa - South                                NaN
#             Tulsa - Southeast                            NaN
#             Union                                        0.0
#             Washington County                            NaN
#
#                                       PROPERTY_SINGLEFAMILYRENTAL  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central                                1.0
#             Amarillo - South Central                          NaN
#             Amarillo - Southeast                              NaN
#             Amarillo - Southwest                              NaN
#             Amarillo - West                                   NaN
# ...                                                           ...
# Tulsa       Tulsa - Northeast                                 NaN
#             Tulsa - South                                     NaN
#             Tulsa - Southeast                                 NaN
#             Union                                             NaN
#             Washington County                                 NaN
#
#                                       PROPERTY_CURRENT_OCCUPANCY  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central                         85.950000
#             Amarillo - South Central                   90.422222
#             Amarillo - Southeast                       96.700000
#             Amarillo - Southwest                       91.717647
#             Amarillo - West                            91.810000
# ...                                                          ...
# Tulsa       Tulsa - Northeast                          83.266667
#             Tulsa - South                              94.122500
#             Tulsa - Southeast                          93.620000
#             Union                                      94.150000
#             Washington County                          81.860000
#
#                                       PROPERTY_CURRENT_RENT  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central                   752.166667
#             Amarillo - South Central             725.777778
#             Amarillo - Southeast                 893.000000
#             Amarillo - Southwest                 908.117647
#             Amarillo - West                      771.000000
# ...                                                     ...
# Tulsa       Tulsa - Northeast                    762.666667
#             Tulsa - South                        736.575000
#             Tulsa - Southeast                    869.666667
#             Union                                929.950000
#             Washington County                    781.200000
#
#                                       PROPERTY_RENTPERSQFT  \
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central                    0.007936
#             Amarillo - South Central              0.008388
#             Amarillo - Southeast                  0.003715
#             Amarillo - Southwest                  0.004799
#             Amarillo - West                       0.007184
# ...                                                    ...
# Tulsa       Tulsa - Northeast                     0.004573
#             Tulsa - South                         0.006817
#             Tulsa - Southeast                     0.008911
#             Union                                 0.004343
#             Washington County                     0.010668
#
#                                       PROPERTY_RENTPERSQFTALLUNITS
# MARKET_NAME SUBMARKET_NAME
# Amarillo    Amarillo - Central                            0.947847
#             Amarillo - South Central                      1.025155
#             Amarillo - Southeast                          0.891663
#             Amarillo - Southwest                          1.076117
#             Amarillo - West                               0.934105
# ...                                                            ...
# Tulsa       Tulsa - Northeast                             0.847112
#             Tulsa - South                                 0.941775
#             Tulsa - Southeast                             1.097138
#             Union                                         1.087481
#             Washington County                             0.979437
#
# [409 rows x 16 columns]

# %% [markdown]
# ## Filter 3: Removing properties with no SQFT information

# %%
filter3 = filter2[filter2.PROPERTY_SQFT > 0]

# %% [markdown]
# ## Filter 4: Removing Student, Affordable, Military, Age Restricted Housing

# %%
filter4 = filter3[(filter3.PROPERTY_STUDENTHOUSING == 'N') & (filter3.PROPERTY_AFFORDABLEHOUSING == 'N') & (filter3.PROPERTY_MILITARYHOUSING == 'N') & (filter3.PROPERTY_AGERESTRICTED == 'N')]

# %% [markdown]
# ## Filter 5: Removing Property with no Submarket

# %%
filter5 = filter4.dropna(subset = ['SUBMARKET_NAME'])

# %%
mean_submarket = filter5.groupby(['SUBMARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.mean()
mean_submarket_dict = mean_submarket.to_dict()
filter5['mean_submarket'] = filter5['SUBMARKET_NAME'].map(mean_submarket_dict)
# Out:
# <ipython-input-17-c0a6ceaa8555>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter5['mean_submarket'] = filter5['SUBMARKET_NAME'].map(mean_submarket_dict)

# %%
min_submarket = filter5.groupby(['SUBMARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.min()
min_submarket_dict = min_submarket.to_dict()
filter5['min_submarket'] = filter5['SUBMARKET_NAME'].map(min_submarket_dict)
# Out:
# <ipython-input-18-9ad76378064d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter5['min_submarket'] = filter5['SUBMARKET_NAME'].map(min_submarket_dict)

# %%
max_submarket = filter5.groupby(['SUBMARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.max()
max_submarket_dict = max_submarket.to_dict()
filter5['max_submarket'] = filter5['SUBMARKET_NAME'].map(max_submarket_dict)
# Out:
# <ipython-input-19-c07110e66468>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter5['max_submarket'] = filter5['SUBMARKET_NAME'].map(max_submarket_dict)

# %%
mean_market = filter5.groupby(['MARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.mean()
mean_market_dict = mean_market.to_dict()
filter5['mean_market'] = filter5['MARKET_NAME'].map(mean_market_dict)
# Out:
# <ipython-input-20-7ddbc10c556d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter5['mean_market'] = filter5['MARKET_NAME'].map(mean_market_dict)

# %%
min_market = filter5.groupby(['MARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.min()
min_market_dict = min_market.to_dict()
filter5['min_market'] = filter5['MARKET_NAME'].map(min_market_dict)
# Out:
# <ipython-input-21-1441601ffac4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter5['min_market'] = filter5['MARKET_NAME'].map(min_market_dict)

# %%
max_market = filter5.groupby(['MARKET_NAME']).PROPERTY_RENTPERSQFTALLUNITS.max()
max_market_dict = max_market.to_dict()
filter5['max_market'] = filter5['MARKET_NAME'].map(max_market_dict)
# Out:
# <ipython-input-22-95ad7e0cfda0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter5['max_market'] = filter5['MARKET_NAME'].map(max_market_dict)

# %%
filter5.shape
# Out:
# (6780, 45)

# %%
filter5.columns
# Out:
# Index(['PROPERTY_ID', 'MARKETID', 'MARKET_NAME', 'SUBMARKET_CODE',
#        'SUBMARKET_NAME', 'COUNTY_NAME', 'PROPERTY_NAME', 'PROPERTY_PRIORNAMES',
#        'PROPERTY_ADDRESS', 'PROPERTY_CITY', 'PROPERTY_STATE',
#        'PROPERTY_ZIPCODE', 'PROPERTY_LATITUDE', 'PROPERTY_LONGITUDE',
#        'PROPERTY_PHONE', 'PROPERTY_UNITS', 'PROPERTY_SQFT', 'PROPERTY_ACRES',
#        'PROPERTY_IMPRATING', 'PROPERTY_LOCRATING', 'PROPERTY_STATUS',
#        'PROPERTY_DATE_PLANNED', 'PROPERTY_DATE_UNDERCONSTRUCTION',
#        'PROPERTY_DATE_RENTUP', 'PROPERTY_DATECOMPLETED', 'PROPERTY_MIXEDUSE',
#        'PROPERTY_MIXEDUSE_NOTES', 'PROPERTY_STUDENTHOUSING',
#        'PROPERTY_AFFORDABLEHOUSING', 'PROPERTY_MILITARYHOUSING',
#        'PROPERTY_AGERESTRICTED', 'PROPERTY_FRACTUREDCONDO',
#        'PROPERTY_ADAPTIVEREUSE', 'PROPERTY_SINGLEFAMILYRENTAL',
#        'PROPERTY_CURRENT_OCCUPANCY', 'PROPERTY_CURRENT_RENT',
#        'PROPERTY_MATRIX_URL', 'PROPERTY_RENTPERSQFT',
#        'PROPERTY_RENTPERSQFTALLUNITS', 'mean_submarket', 'min_submarket',
#        'max_submarket', 'mean_market', 'min_market', 'max_market'],
#       dtype='object')

# %%
filter5 = filter5.loc[:,['PROPERTY_ID', 'MARKETID', 'MARKET_NAME', 'SUBMARKET_CODE', 'SUBMARKET_NAME', 'COUNTY_NAME', 'PROPERTY_NAME', 'PROPERTY_PRIORNAMES','PROPERTY_ADDRESS', 'PROPERTY_CITY', 'PROPERTY_STATE','PROPERTY_ZIPCODE', 'PROPERTY_LATITUDE', 'PROPERTY_LONGITUDE', 'PROPERTY_UNITS', 'PROPERTY_SQFT', 'PROPERTY_ACRES','PROPERTY_IMPRATING', 'PROPERTY_LOCRATING', 'PROPERTY_DATECOMPLETED','PROPERTY_CURRENT_OCCUPANCY', 'PROPERTY_CURRENT_RENT','PROPERTY_RENTPERSQFT','PROPERTY_RENTPERSQFTALLUNITS', 'mean_submarket', 'min_submarket','max_submarket', 'mean_market', 'min_market', 'max_market']]

# %% [markdown]
# ## Filter 6: Removing Property with missing IMP/LOC rating

# %%
filter5['PROPERTY_IMPRATING'].isnull().sum()
filter5['PROPERTY_LOCRATING'].isnull().sum()
# Out:
# 0

# %%
filter5['PROPERTY_IMPRATING'].replace('', np.nan, inplace=True)
filter5['PROPERTY_LOCRATING'].replace('', np.nan, inplace=True)

# %%
filter6 = filter5.dropna(subset=['PROPERTY_IMPRATING','PROPERTY_LOCRATING'])

# %%
final_data = filter6

# %%
final_data.shape
# Out:
# (6774, 30)

# %%
final_data = final_data.reset_index(drop=True)

# %%
final_data.to_excel('SouthWest_FilterData.xlsx')
